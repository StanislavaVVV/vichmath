# %%
import matplotlib.pyplot as plt
import math
import numpy as np
x = []
y3 = []
y5 = []

file = ("h.txt")
f = open(file,'r')
z = f.read()
arr = z.split()


number = len(arr)

for i in range(number):
    x.append(math.log10(float( arr[i] )))
    
    
    
    
    
    
file = ("ln3.txt")
f = open(file,'r')
z = f.read()
arr = z.split()


number = len(arr)

for i in range(number):
    y3.append(math.log10(float( arr[i] )))
    
    
file = ("ln5.txt")
f = open(file,'r')
z = f.read()
arr = z.split()


number = len(arr)

for i in range(number):
    y5.append(math.log10(float( arr[i] )))
    
    
    

    
    
fig,ax=plt.subplots()
ax.set_title("log(err) from log(h)")
ax.plot(x,y3,"r", markersize=5, label='N = 3' )
ax.plot(x,y5,"b", markersize=5, label='N = 5')
ax.legend()
plt.show()



x1 = []
y1 = []


for i in range(len(x)):
    if y[i] == min(y):
        min_num = i


for i in range(min_num):
    x1.append(x[i])
    y1.append(y[i])

#print(x1,y1)

#полином 1 степени по функции
p = np.polyfit(x1,y1, 1)
#подставляем значения x к полученному полиному

print( "k = " + str(p[0]) + " for N = 3")

ya = np.polyval(p, x)
# Out:
# k = 1.0000000000000002 for N = 3

# %%
# Out:
# 1600

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
x = []
y3 = []
y5 = []

file = ("h.txt")
f = open(file,'r')
z = f.read()
arr = z.split()


number = len(arr)

for i in range(number):
    x.append(float( arr[i] ))
    
    
    
    
    
    
file = ("ln3.txt")
f = open(file,'r')
z = f.read()
arr = z.split()


number = len(arr)

for i in range(number):
    y3.append(float( arr[i] ))
    
    
file = ("ln5.txt")
f = open(file,'r')
z = f.read()
arr = z.split()


number = len(arr)

for i in range(number):
    y5.append(float( arr[i] ))
    
    
    

    
    
fig,ax=plt.subplots()
ax.set_title("log(err) from log(h)")
ax.plot(x,y3,"r", markersize=5)
#ax.plot(x,y5,"b", markersize=5)
plt.show()
